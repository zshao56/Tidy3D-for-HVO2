# %%
import numpy as np
import matplotlib.pyplot as plt
import tidy3d as td
from tidy3d import web

# %%
t_total = 0.1
# t is the thickness of HxVO2 in HcVO2

# %%
medium_HxVO2 = td.PoleResidue.from_file(r"F:\OneDrive - UW-Madison\python\tidy 3d\data\nkmodule\VO2-HT.json")
medium_VO2 = td.PoleResidue.from_file(r"F:\OneDrive - UW-Madison\python\tidy 3d\data\nkmodule\VO2-LT.json")
medium_Al2O3 = td.PoleResidue.from_file(r"F:\OneDrive - UW-Madison\python\tidy 3d\data\nkmodule\Al2O3.json")
wl_start = 5  # wavelength
wl_end = 15 # wavelength
freq_start = td.C_0 / wl_end
freq_end = td.C_0 / wl_start

# %%
freqs = np.linspace(freq_start, freq_end, 100)  # freqeucny range of the simulation
freq0 = (freq_start + freq_end)/2  # central frequency
freqw = (freq_end - freq_start) / 2.0  # width of the frequency range

# distance between the surface of the sphere and the start of the PML layers along each cartesian direction
buffer_PML = 1
buffer_source = 0.5
w_size_xy = 0.05
# set the domain size in x, y, and z

# %%
def run_simulation(t_VO2):
    domain_size_xy = w_size_xy
    t_HxVO2 = t_total -t_VO2
    domain_size_z = buffer_PML + t_VO2 + t_HxVO2 + buffer_PML
    
    # construct simulation size array
    sim_size = (domain_size_xy, domain_size_xy, domain_size_z)
    
    VO2_center = t_VO2 / 2
    HxVO2_center = t_VO2 + t_HxVO2 / 2
    
    Al2O3_center = -domain_size_z
    
    t_Al2O3 = 2 * domain_size_z

    
    
    slabs = []
    
    slab_1 = td.Structure(
        geometry = td.Box(
            center = (0, 0, VO2_center),
            size = (w_size_xy, w_size_xy, t_VO2),
        ),
        medium = medium_VO2,
    )
    
    slab_2 = td.Structure(
        geometry = td.Box(
            center = (0, 0, HxVO2_center),
            size = (td.inf, td.inf, t_HxVO2),
        ),
        medium = medium_HxVO2,
    )
    
    slab_3 = td.Structure(
        geometry = td.Box(
            center = (0, 0, Al2O3_center),
            size = (td.inf, td.inf, t_Al2O3),
        ),
        medium = medium_Al2O3,
    )
    slabs = [slab_1, slab_2, slab_3]
    
    source = td.PlaneWave(
        source_time=td.GaussianPulse(freq0=freq0, fwidth=0.5 * freqw),
        size=(td.inf, td.inf, 0),
        center=(0, 0, buffer_source),
        direction="-",
        pol_angle=0,
    )
    
    # add a flux monitor to detect transmission
    monitor_r = td.FluxMonitor(
        center=[0, 0, buffer_source + 0.1], size=[td.inf, td.inf, 0], freqs=freqs, name="R"
    )
    
    # add a field monitor to see the field profile at the absorption peak frequency
    monitor_field = td.FieldMonitor(
        center=[0, 0, 0], size=[td.inf, 0, td.inf], freqs=[freq0], name="field"
    )
    run_time = 2e-11  # simulation run time
    
    refine_box = td.MeshOverrideStructure(
    geometry=td.Box(center=(0, 0, 0), size=(td.inf, td.inf, 0.2)),
    dl=[None, None, 0.005],
    )  
    # set up simulation
    sim = td.Simulation(
        size=sim_size,
        grid_spec=td.GridSpec.auto(wavelength=5,
        min_steps_per_wvl=20,
        override_structures=[refine_box],),
        structures=slabs,
        sources=[source],
        monitors=[monitor_r, monitor_field],
        run_time=run_time,
        boundary_spec=td.BoundarySpec(
            x=td.Boundary.periodic(), y=td.Boundary.periodic(), z=td.Boundary.pml()
        ),
    )
    source.source_time.plot(np.linspace(0, run_time/10, 1001))
    plt.show()
    
    def plot_sim_grid(sim):
        fig, ax = plt.subplots(1, 2, figsize=(12, 6))
        sim.plot(x=0, ax=ax[0])
        sim.plot_grid(x=0, ax=ax[0], lw=0.4, colors="r")
        ax[0].set_xlim(-0.05, 0.05)
        ax[0].set_ylim(-0.1, 0.1)
        sim.plot(z=0, ax=ax[1])
        sim.plot_grid(z=0, ax=ax[1], lw=0.4, colors="r")
        ax[1].set_xlim(-0.6, 0.6)
        ax[1].set_ylim(-0.4, 0.4)
        print(f"Total number of grid points (millions): {sim.num_cells / 1e6:1.2}")
    
        return ax
    ax = plot_sim_grid(sim)

    source.source_time.plot_spectrum(
        times=np.linspace(0, run_time/10, 2000), val="abs"
    )
    plt.show()
    cfig, ax = plt.subplots(1, 2, figsize=(7, 3))
    sim.plot(y=0, ax=ax[0])
    sim.plot(z=0, freq=freq0, ax=ax[1])
    plt.show()
    task_id = web.upload(sim, task_name=f"HVO2-{t_VO2}")
    
    estimated_cost = web.estimate_cost(task_id)
    print(f'The estimated maximum cost is {estimated_cost:.3f} Flex Credits.')
    web.start(task_id)
    web.monitor(task_id, verbose=True)
    
    import time
    time.sleep(20)
    print("Billed flex unit cost: ", web.real_cost(task_id))
    
    sim_data = web.load(task_id, path=f"data/HVO{t_VO2}.hdf5")
    
    # Show the output of the log file
    print(sim_data.log)
    R = sim_data["R"].flux
    A = 1 - R
    plt.plot(td.C_0 /freqs, R, td.C_0 /freqs, A)
    
    plt.xlabel("Wavelength (μm)")
    plt.ylabel("Optical Property")
    plt.ylim(0, 1)
    plt.legend(("R", "A"))
    plt.show()
    
    ax = sim_data.plot_field(field_monitor_name="field", field_name="E", val="abs^2")
    plt.show()
    
for t_VO2 in np.arange(0.01, 0.10, 0.01):
    t_VO2 = round(t_VO2, 2)
    #prevent t from containing too many digits
    run_simulation(t_VO2)
# Out:
# 16:12:32 ?????? WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:12:33 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.01' with task_id
#                 'fdve-60ec0772-1116-4955-b241-616e44d77f26' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=315959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-60ec0772-1116-4955-b241-616e44d77f26\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=368579;https://tidy3d.simulation.cloud/workbench?taskId=fdve-60ec0772-1116-4955-b241-616e44d77f26\taskId]8;;\]8;id=315959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-60ec0772-1116-4955-b241-616e44d77f26\=]8;;\]8;id=798252;https://tidy3d.simulation.cloud/workbench?taskId=fdve-60ec0772-1116-4955-b241-616e44d77f26\fdve]8;;\]8;id=315959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-60ec0772-1116-4955-b241-616e44d77f26\-60ec0772-]8;;\
#                 ]8;id=315959;https://tidy3d.simulation.cloud/workbench?taskId=fdve-60ec0772-1116-4955-b241-616e44d77f26\1116-4955-b241-616e44d77f26']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:12:34 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:12:35 ?????? status = success
# 16:12:55 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:12:56 ?????? loading simulation from data/HVO0.01.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.4730
# Compute monitor modes time (s):    0.0045
# Rest of setup time (s):            2.3416
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 4.31e-09
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.8399
# Data write time (s):               0.0025
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:12:57 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.02' with task_id
#                 'fdve-7c487357-e5c3-41fc-878c-e35a1a862244' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=455710;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=595823;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\taskId]8;;\]8;id=455710;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\=]8;;\]8;id=95886;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\fdve]8;;\]8;id=455710;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\-7c487357-]8;;\
#                 ]8;id=455710;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\e5c3-41fc-878c-e35a1a862244']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:12:58 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:12:59 ?????? status = queued
# 16:13:04 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:13:10 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
#                 running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:13:24 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:13:25 ?????? status = postprocess
# 16:13:29 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:13:30 ?????? View simulation result at
#                 ]8;id=272245;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=701495;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\taskId]8;;\]8;id=272245;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\=]8;;\]8;id=651114;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\fdve]8;;\]8;id=272245;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\-7c487357-]8;;\
#                 ]8;id=272245;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7c487357-e5c3-41fc-878c-e35a1a862244\e5c3-41fc-878c-e35a1a862244']8;;\.
# 16:13:50 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:13:51 ?????? loading simulation from data/HVO0.02.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.4982
# Compute monitor modes time (s):    0.0044
# Rest of setup time (s):            2.2900
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 5.32e-09
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.7887
# Data write time (s):               0.0025
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:13:52 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.03' with task_id
#                 'fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=724796;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=901069;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\taskId]8;;\]8;id=724796;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\=]8;;\]8;id=255291;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\fdve]8;;\]8;id=724796;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\-8dcaa238-]8;;\
#                 ]8;id=724796;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\29f6-4d08-895a-42936ddbefd5']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:13:54 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:13:55 ?????? status = queued
# 16:13:59 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:14:05 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
#                 running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:14:19 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:14:20 ?????? status = postprocess
# 16:14:24 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:14:25 ?????? View simulation result at
#                 ]8;id=818137;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=650180;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\taskId]8;;\]8;id=818137;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\=]8;;\]8;id=380504;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\fdve]8;;\]8;id=818137;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\-8dcaa238-]8;;\
#                 ]8;id=818137;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8dcaa238-29f6-4d08-895a-42936ddbefd5\29f6-4d08-895a-42936ddbefd5']8;;\.
# 16:14:45 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:14:46 ?????? loading simulation from data/HVO0.03.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.5141
# Compute monitor modes time (s):    0.0042
# Rest of setup time (s):            2.3922
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 6.71e-09
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.8483
# Data write time (s):               0.0027
# 16:14:47 ?????? WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:14:48 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.04' with task_id
#                 'fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=969362;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=834342;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\taskId]8;;\]8;id=969362;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\=]8;;\]8;id=896568;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\fdve]8;;\]8;id=969362;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\-1b4a8e5f-]8;;\
#                 ]8;id=969362;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\998f-41f0-b17d-7c92bafa011d']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:14:49 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:14:50 ?????? status = queued
# 16:14:54 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:14:58 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
#                 running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:15:12 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                 status = postprocess
# 16:15:17 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:15:18 ?????? View simulation result at
#                 ]8;id=354368;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=23683;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\taskId]8;;\]8;id=354368;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\=]8;;\]8;id=362763;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\fdve]8;;\]8;id=354368;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\-1b4a8e5f-]8;;\
#                 ]8;id=354368;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1b4a8e5f-998f-41f0-b17d-7c92bafa011d\998f-41f0-b17d-7c92bafa011d']8;;\.
# 16:15:38 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:15:39 ?????? loading simulation from data/HVO0.04.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.3454
# Compute monitor modes time (s):    0.0042
# Rest of setup time (s):            2.3506
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 8.49e-09
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.8549
# Data write time (s):               0.0026
# 16:15:40 ?????? WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:15:41 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.05' with task_id
#                 'fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=746960;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=148814;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\taskId]8;;\]8;id=746960;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\=]8;;\]8;id=987504;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\fdve]8;;\]8;id=746960;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\-5dc96c3a-]8;;\
#                 ]8;id=746960;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\5ebb-4151-9568-18d9410d54e4']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:15:42 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:15:43 ?????? status = queued
# 16:15:47 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:15:54 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
#                 running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:16:08 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:16:09 ?????? status = postprocess
# 16:16:13 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:16:14 ?????? View simulation result at
#                 ]8;id=868775;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=246211;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\taskId]8;;\]8;id=868775;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\=]8;;\]8;id=483303;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\fdve]8;;\]8;id=868775;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\-5dc96c3a-]8;;\
#                 ]8;id=868775;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5dc96c3a-5ebb-4151-9568-18d9410d54e4\5ebb-4151-9568-18d9410d54e4']8;;\.
# 16:16:34 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:16:35 ?????? loading simulation from data/HVO0.05.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.5162
# Compute monitor modes time (s):    0.0043
# Rest of setup time (s):            2.2914
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 1.13e-08
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.7683
# Data write time (s):               0.0026
# 16:16:36 ?????? WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:16:37 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.06' with task_id
#                 'fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=533767;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=650698;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\taskId]8;;\]8;id=533767;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\=]8;;\]8;id=764423;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\fdve]8;;\]8;id=533767;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\-b5ec3888-]8;;\
#                 ]8;id=533767;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\3a13-4645-85ea-9dd4e1d60807']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:16:38 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:16:39 ?????? status = queued
# 16:16:43 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:16:49 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
#                 running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:17:04 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                 status = postprocess
# 16:17:09 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                 View simulation result at
#                 ]8;id=718740;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=813896;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\taskId]8;;\]8;id=718740;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\=]8;;\]8;id=367137;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\fdve]8;;\]8;id=718740;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\-b5ec3888-]8;;\
#                 ]8;id=718740;https://tidy3d.simulation.cloud/workbench?taskId=fdve-b5ec3888-3a13-4645-85ea-9dd4e1d60807\3a13-4645-85ea-9dd4e1d60807']8;;\.
# 16:17:29 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:17:30 ?????? loading simulation from data/HVO0.06.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
# 16:17:31 ?????? WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.5151
# Compute monitor modes time (s):    0.0046
# Rest of setup time (s):            2.3322
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 1.51e-08
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.7147
# Data write time (s):               0.0025
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:17:32 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.07' with task_id
#                 'fdve-998d91ae-5291-4046-9a13-d7ac67ba693b' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=500151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=873281;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\taskId]8;;\]8;id=500151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\=]8;;\]8;id=20925;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\fdve]8;;\]8;id=500151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\-998d91ae-]8;;\
#                 ]8;id=500151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\5291-4046-9a13-d7ac67ba693b']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:17:34 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:17:35 ?????? status = queued
# 16:17:39 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:17:45 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
#                 running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:18:00 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                 status = postprocess
# 16:18:05 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                 View simulation result at
#                 ]8;id=432164;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=755115;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\taskId]8;;\]8;id=432164;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\=]8;;\]8;id=805101;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\fdve]8;;\]8;id=432164;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\-998d91ae-]8;;\
#                 ]8;id=432164;https://tidy3d.simulation.cloud/workbench?taskId=fdve-998d91ae-5291-4046-9a13-d7ac67ba693b\5291-4046-9a13-d7ac67ba693b']8;;\.
# 16:18:25 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:18:26 ?????? loading simulation from data/HVO0.07.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.5541
# Compute monitor modes time (s):    0.0043
# Rest of setup time (s):            2.2531
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 2.22e-08
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.6925
# Data write time (s):               0.0025
# 16:18:27 ?????? WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:18:28 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.08' with task_id
#                 'fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=817111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=723228;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\taskId]8;;\]8;id=817111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\=]8;;\]8;id=545623;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\fdve]8;;\]8;id=817111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\-d01bcc90-]8;;\
#                 ]8;id=817111;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\2460-4c00-bb8a-b21b487165e0']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:18:29 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:18:30 ?????? status = queued
# 16:18:34 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:18:40 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
#                 running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:18:55 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                 status = postprocess
# 16:19:00 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                 View simulation result at
#                 ]8;id=790059;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=750917;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\taskId]8;;\]8;id=790059;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\=]8;;\]8;id=347373;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\fdve]8;;\]8;id=790059;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\-d01bcc90-]8;;\
#                 ]8;id=790059;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d01bcc90-2460-4c00-bb8a-b21b487165e0\2460-4c00-bb8a-b21b487165e0']8;;\.
# 16:19:21 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                 loading simulation from data/HVO0.08.hdf5
# 16:19:22 ?????? WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.5244
# Compute monitor modes time (s):    0.0046
# Rest of setup time (s):            2.2783
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 3.59e-08
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.7932
# Data write time (s):               0.0025
# 16:19:23 ?????? WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Total number of grid points (millions): 0.00037
# 16:19:24 ?????? WARNING: Simulation has 1.26e+06 time steps. The 'run_time' may
#                 be unnecessarily large, unless there are very long-lived
#                 resonances.
#                 Created task 'HVO2-0.09' with task_id
#                 'fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72' and task_type
#                 'FDTD'.
#                 View task using web UI at
#                 ]8;id=513940;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=213167;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\taskId]8;;\]8;id=513940;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\=]8;;\]8;id=453245;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\fdve]8;;\]8;id=513940;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\-e7c481ce-]8;;\
#                 ]8;id=513940;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\6d77-44b6-9ea8-abad4a162c72']8;;\.
# E:\software\Anaconda\envs\Tidy3D310\lib\site-packages\rich\live.py:229:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:19:25 ?????? Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#                 execution details. Use 'web.real_cost(task_id)' to get the
#                 billed FlexCredit cost after a simulation run.
# The estimated maximum cost is 0.025 Flex Credits.
# 16:19:26 ?????? status = queued
# 16:19:30 ?????? status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:19:36 ?????? Maximum FlexCredit cost: 0.025. Use 'web.real_cost(task_id)' to
#                 get the billed FlexCredit cost after a simulation run.
#                 starting up solver
# 16:19:37 ?????? running solver
#                 To cancel the simulation, use 'web.abort(task_id)' or
#                 'web.delete(task_id)' or abort/delete the task in the web UI.
#                 Terminating the Python script will not stop the job running on
#                 the cloud.
# 16:19:51 ?????? early shutoff detected at 4%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                 status = postprocess
# 16:19:56 ?????? status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 16:19:57 ?????? View simulation result at
#                 ]8;id=485292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=978110;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\taskId]8;;\]8;id=485292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\=]8;;\]8;id=852817;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\fdve]8;;\]8;id=485292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\-e7c481ce-]8;;\
#                 ]8;id=485292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e7c481ce-6d77-44b6-9ea8-abad4a162c72\6d77-44b6-9ea8-abad4a162c72']8;;\.
# 16:20:17 ?????? Billed flex credit cost: 0.025.
#                 Note: the task cost pro-rated due to early shutoff was below the
#                 minimum threshold, due to fast shutoff. Decreasing the
#                 simulation 'run_time' should decrease the estimated, and
#                 correspondingly the billed cost of such tasks.
# Billed flex unit cost:  0.025
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 16:20:18 ?????? loading simulation from data/HVO0.09.hdf5
#                 WARNING: Structure at 'structures[0]' has bounds that extend
#                 exactly to simulation edges. This can cause unexpected behavior.
#                 If intending to extend the structure to infinity along one
#                 dimension, use td.inf as a size variable instead to make this
#                 explicit.
#                 WARNING: Suppressed 3 WARNING messages.
#                 WARNING: Structure at structures[0] was detected as being less
#                 than half of a central wavelength from a PML on side z-min. To
#                 avoid inaccurate results or divergence, please increase gap
#                 between any structures and PML or fully extend structure through
#                 the pml.
#                 WARNING: Suppressed 4 WARNING messages.
# Simulation domain Nx, Ny, Nz: [2, 2, 92]
# Applied symmetries: (0, 0, 0)
# Number of computational grid points: 3.7600e+02.
# Using subpixel averaging: True
# Number of time steps: 1.2602e+06
# Automatic shutoff factor: 1.00e-05
# Time step (s): 1.5870e-17
#
#
# Compute source modes time (s):     0.4632
# Compute monitor modes time (s):    0.0042
# Rest of setup time (s):            2.2683
#
# Running solver for 1260244 time steps...
# - Time step   5018 / time 7.96e-14s (  0 % done), field decay: 1.00e+00
# - Time step  50409 / time 8.00e-13s (  4 % done), field decay: 6.96e-08
# Field decay smaller than shutoff factor, exiting solver.
#
# Solver time (s):                   8.6961
# Data write time (s):               0.0025
